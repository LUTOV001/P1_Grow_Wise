# %%
import yfinance as yf
from yahoo_fin.stock_info import get_data

# requires python 3.9 min

# %%
'''https://algotrading101.com/learn/yahoo-finance-api-guide/'''
# Out:
# 'https://algotrading101.com/learn/yahoo-finance-api-guide/'

# %%
amazon_weekly = get_data("amzn", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
amazon_weekly
# Out:
#                   open        high         low       close    adjclose
# 2023-01-01   85.459999   86.980003   81.430000   86.080002   86.080002  \
# 2023-01-08   87.459999   98.370003   87.080002   98.120003   98.120003
# 2023-01-15   98.680000   99.320000   92.860001   97.250000   97.250000
# 2023-01-22   97.559998  103.489998   91.519997  102.239998  102.239998
# 2023-01-29  101.089996  114.000000   99.010002  103.389999  103.389999
# 2023-02-05  102.930000  103.949997   96.230003   97.610001   97.610001
# 2023-02-12   97.849998  101.169998   95.650002   97.199997   97.199997
# 2023-02-19   95.339996   97.010002   92.320000   93.500000   93.500000
# 2023-02-26   94.279999   94.940002   90.389999   94.900002   94.900002
# 2023-03-05   95.190002   96.550003   90.250000   90.730003   90.730003
# 2023-03-12   89.970001  100.989998   88.120003   98.949997   98.949997
# 2023-03-19   98.410004  102.099998   95.699997   98.129997   98.129997
# ...

# %%
# facebook_weekly = get_data("fb", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
# facebook_weekly
'''doesn't like fb... is it meta now?'''
# Out:
# "doesn't like fb... is it meta now?"

# %%
microsoft_weekly = get_data("msft", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
microsoft_weekly
# Out:
#                   open        high         low       close    adjclose
# 2023-01-01  243.080002  245.750000  219.350006  224.929993  224.368011  \
# 2023-01-08  226.449997  239.899994  226.410004  239.229996  238.632294
# 2023-01-15  237.970001  242.380005  230.679993  240.220001  239.619827
# 2023-01-22  241.100006  249.830002  230.899994  248.160004  247.539993
# 2023-01-29  244.509995  264.690002  242.199997  258.350006  257.704529
# 2023-02-05  257.440002  276.760010  254.779999  263.100006  262.442657
# 2023-02-12  267.640015  274.970001  256.000000  258.059998  257.415253
# 2023-02-19  254.479996  256.839996  248.100006  249.220001  249.220001
# 2023-02-26  252.460007  255.619995  245.610001  255.289993  255.289993
# 2023-03-05  256.429993  260.119995  247.600006  248.589996  248.589996
# 2023-03-12  247.399994  283.329987  245.729996  279.429993  279.429993
# 2023-03-19  276.980011  281.059998  269.519989  280.570007  280.570007
# ...

# %%
nvidia_weekly = get_data("nvda", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
nvidia_weekly
# Out:
#                   open        high         low       close    adjclose
# 2023-01-01  148.509995  150.100006  140.339996  148.589996  148.564758  \
# 2023-01-08  152.839996  169.220001  151.410004  168.990005  168.961304
# 2023-01-15  168.990005  178.729996  167.309998  178.389999  178.359711
# 2023-01-22  180.639999  206.279999  178.179993  203.649994  203.615417
# 2023-01-29  199.500000  219.490005  189.500000  211.000000  210.964172
# 2023-02-05  208.059998  230.199997  207.860001  212.649994  212.613876
# 2023-02-12  215.380005  230.490005  209.619995  213.880005  213.843689
# 2023-02-19  210.000000  238.880005  204.210007  232.860001  232.820465
# 2023-02-26  236.699997  239.000000  224.320007  238.899994  238.859421
# 2023-03-05  238.910004  244.539993  227.259995  229.649994  229.610992
# 2023-03-12  227.520004  263.989990  222.970001  257.250000  257.250000
# 2023-03-19  256.149994  275.890015  251.300003  267.790009  267.790009
# ...

# %%
supermicro_weekly = get_data("smci", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
supermicro_weekly
# Out:
#                   open        high         low       close    adjclose
# 2023-01-01   83.080002   87.739998   79.629997   84.389999   84.389999  \
# 2023-01-08   85.949997   92.800003   74.040001   80.580002   80.580002
# 2023-01-15   80.550003   86.820000   69.019997   71.980003   71.980003
# 2023-01-22   72.959999   79.739998   71.510002   74.300003   74.300003
# 2023-01-29   73.070000   85.849998   70.110001   84.339996   84.339996
# 2023-02-05   83.500000   93.879997   80.000000   90.019997   90.019997
# 2023-02-12   89.449997   97.959999   87.599998   91.980003   91.980003
# 2023-02-19   90.500000   98.360001   85.610001   98.160004   98.160004
# 2023-02-26   98.860001  103.980003   95.099998   97.830002   97.830002
# 2023-03-05   98.849998  104.300003   92.089996   92.760002   92.760002
# 2023-03-12   91.000000   98.040001   87.250000   95.500000   95.500000
# 2023-03-19   95.489998  118.360001   95.410004  110.830002  110.830002
# ...

# %%
qqq_weekly = get_data("qqq", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
qqq_weekly
# Out:
#                   open        high         low       close    adjclose
# 2023-01-01  268.649994  270.149994  260.339996  268.799988  268.384491  \
# 2023-01-08  270.829987  281.220001  268.970001  280.970001  280.535706
# 2023-01-15  280.769989  284.690002  273.890015  282.679993  282.243042
# 2023-01-22  283.540009  298.260010  281.179993  296.260010  295.802063
# 2023-01-29  292.929993  313.679993  289.890015  306.179993  305.706726
# 2023-02-05  303.510010  311.029999  297.250000  299.700012  299.236755
# 2023-02-12  301.130005  309.269989  298.100006  301.160004  300.694489
# 2023-02-19  297.260010  298.730011  290.049988  291.850006  291.398895
# 2023-02-26  295.070007  299.920013  288.369995  299.679993  299.216766
# 2023-03-05  300.940002  304.000000  287.380005  288.549988  288.103973
# 2023-03-12  286.730011  309.149994  285.190002  305.359985  304.887970
# 2023-03-19  304.260010  315.250000  302.010010  310.890015  310.409454
# ...

# %%
ndxt_weekly = get_data("ndxt", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
ndxt_weekly
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ndxt_weekly = get_data("ndxt", start_date="01/01/2023", end_date="05/06/2023", index_as_date = True, interval="1wk")
#       2 ndxt_weekly
#
# File /opt/anaconda3/envs/py39/lib/python3.9/site-packages/yahoo_fin/stock_info.py:90, in get_data(ticker, start_date, end_date, index_as_date, interval, headers)
#      86 resp = requests.get(site, params = params, headers = headers)
#      89 if not resp.ok:
# ---> 90     raise AssertionError(resp.json())
#      93 # get JSON response
#      94 data = resp.json()
#
# AssertionError: {'chart': {'result': None, 'error': {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}}}

# %%
# example w/ multiple tickers
# this pulls the data into a cache
ticker_list = ["amzn", "aapl", "ba"]
historical_datas = {}
for ticker in ticker_list:
    historical_datas[ticker] = get_data(ticker)

# %%
# how to call an individual ticker from historical_datas
historical_datas["aapl"]
# Out:
#                   open        high         low       close    adjclose
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722  \
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-05-01  169.279999  170.449997  168.639999  169.589996  169.589996
# 2023-05-02  170.089996  170.350006  167.539993  168.539993  168.539993
# 2023-05-03  169.500000  170.919998  167.160004  167.449997  167.449997
# 2023-05-04  164.889999  167.039993  164.309998  165.789993  165.789993
# 2023-05-05  170.979996  174.300003  170.759995  173.570007  173.570007
#
#                volume ticker
# 1980-12-12  469033600   AAPL
# 1980-12-15  175884800   AAPL
# ...

# %%
# how to return all tickers with Dow Jones
import yahoo_fin.stock_info as si
dow_list = si.tickers_dow()

# %%
print("Tickers in Dow Jones:", len(dow_list))
dow_list[0:10]
# Out:
# Tickers in Dow Jones: 30
# ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW']

# %%
# Iterate through the list of tickers, appending each time to the dictionary again:
# note that the output is in the form of a dictionary

dow_historical = {}
for ticker in dow_list:
    dow_historical[ticker] = si.get_data(ticker, start_date="01/01/2020", end_date="01/03/2020", interval="1d")
dow_historical
# Out:
# {'AAPL':                  open       high        low      close   adjclose     volume
#  2020-01-02  74.059998  75.150002  73.797501  75.087502  73.449394  135480400  \
#
#             ticker
#  2020-01-02   AAPL  ,
#  'AMGN':              open        high         low       close   adjclose   volume
#  2020-01-02  243.0  243.190002  238.979996  240.100006  217.77124  2088000  \
#
#             ticker
#  2020-01-02   AMGN  ,
#  'AXP':                   open        high         low       close   adjclose
#  2020-01-02  124.660004  126.269997  124.230003  125.849998  120.20771  \
#
#               volume ticker
#  2020-01-02  2708000    AXP  ,
#  'BA':                   open        high         low       close    adjclose
#  2020-01-02  328.549988  333.350006  327.700012  333.320007  331.348572  \
#
#               volume ticker
#  2020-01-02  4544400     BA  ,
#  'CAT':              open        high         low       close   adjclose   volume
# ...
